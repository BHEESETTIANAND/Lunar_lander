# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
# Requirement already satisfied: stable-baselines3==2.0.0a5 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.0a5)
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2)) (4.1.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.28.1)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.10/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.23.5)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.1.0+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.3.5)
# Collecting pygame==2.1.3 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3))
#   Using cached pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (0.18.0)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (1.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (4.66.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.3.0)
# Installing collected packages: pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.1.0
#     Uninstalling pygame-2.1.0:
#       Successfully uninstalled pygame-2.1.0
# Successfully installed pygame-2.1.3

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 23 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.10/dist-packages (3.0)

# %%
import os
os.kill(os.getpid(), 9)

# %%
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login .

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym


env = gym.make("LunarLander-v2")


observation, info = env.reset()

for _ in range(20):

  action = env.action_space.sample()
  print("Action taken:", action)


  observation, reward, terminated, truncated, info = env.step(action)


  if terminated or truncated:

      print("Environment is reset")
      observation, info = env.reset()

env.close()
# Out:
# Action taken: 2
# Action taken: 0
# Action taken: 2
# Action taken: 3
# Action taken: 1
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 1
# Action taken: 2
# Action taken: 3
# Action taken: 3
# Action taken: 2
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 0
# Action taken: 0

# %%
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-4.685106    6.1337695  -3.4197934   4.9305     -2.3691022  -1.3103213
#   0.68336743  0.34288943]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
env = make_vec_env('LunarLander-v2', n_envs=16)

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.9     |
# |    ep_rew_mean     | -183     |
# | time/              |          |
# |    fps             | 2329     |
# |    iterations      | 1        |
# |    time_elapsed    | 7        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.8        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1951        |
# |    iterations           | 2           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006536396 |
# |    clip_fraction        | 0.0334      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00144     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00554    |
# |    value_loss           | 5.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95          |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 1901        |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006771834 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53e+03    |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00494    |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.8        |
# |    ep_rew_mean          | -134        |
# | time/                   |             |
# |    fps                  | 1845        |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006819942 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000369    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 614         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 1767        |
# |    iterations           | 5           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010946693 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00542     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 758         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00732    |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -94.7       |
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 6           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008441536 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.00801     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 330         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 675         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 110          |
# |    ep_rew_mean          | -83.1        |
# | time/                   |              |
# |    fps                  | 1740         |
# |    iterations           | 7            |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0058933906 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 403          |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 631          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -56.6       |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 8           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.007176779 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 175         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 476         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | -38          |
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 9            |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0072513614 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 429          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 1662        |
# |    iterations           | 10          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008113629 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.172       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 232         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 449         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 146         |
# |    ep_rew_mean          | -16.2       |
# | time/                   |             |
# |    fps                  | 1620        |
# |    iterations           | 11          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.009482063 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 204         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00453    |
# |    value_loss           | 457         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | -9.75       |
# | time/                   |             |
# |    fps                  | 1501        |
# |    iterations           | 12          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004873543 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 421         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 6.12         |
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 13           |
# |    time_elapsed         | 152          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0080127325 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 157          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00296     |
# |    value_loss           | 363          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 1348         |
# |    iterations           | 14           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0079149455 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 134          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 327          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | 18.7        |
# | time/                   |             |
# |    fps                  | 1303        |
# |    iterations           | 15          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.006355088 |
# |    clip_fraction        | 0.037       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 262         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | 26.7         |
# | time/                   |              |
# |    fps                  | 1263         |
# |    iterations           | 16           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0051487703 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.745        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 212          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 435          |
# |    ep_rew_mean          | 34.5         |
# | time/                   |              |
# |    fps                  | 1212         |
# |    iterations           | 17           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0069950223 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 170          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 556          |
# |    ep_rew_mean          | 48           |
# | time/                   |              |
# |    fps                  | 1170         |
# |    iterations           | 18           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0067793503 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.8         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 180          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 594          |
# |    ep_rew_mean          | 51.9         |
# | time/                   |              |
# |    fps                  | 1138         |
# |    iterations           | 19           |
# |    time_elapsed         | 273          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0038829863 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 79.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 688          |
# |    ep_rew_mean          | 62.7         |
# | time/                   |              |
# |    fps                  | 1100         |
# |    iterations           | 20           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0033320892 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00091     |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 66.5        |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 21          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.004941444 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.4        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 74.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | 76.4         |
# | time/                   |              |
# |    fps                  | 1056         |
# |    iterations           | 22           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0048483973 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.3         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 155          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 74.9         |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 23           |
# |    time_elapsed         | 361          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0048375106 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 88           |
# |    policy_gradient_loss | 0.000343     |
# |    value_loss           | 88.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 828          |
# |    ep_rew_mean          | 80.5         |
# | time/                   |              |
# |    fps                  | 1019         |
# |    iterations           | 24           |
# |    time_elapsed         | 385          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0044150646 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.6         |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.000808    |
# |    value_loss           | 87.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 812          |
# |    ep_rew_mean          | 82.4         |
# | time/                   |              |
# |    fps                  | 1005         |
# |    iterations           | 25           |
# |    time_elapsed         | 407          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0030717785 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.1         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.000885    |
# |    value_loss           | 73.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 827         |
# |    ep_rew_mean          | 90.2        |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 26          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.003037613 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 69.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 90.1         |
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 27           |
# |    time_elapsed         | 448          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0046653897 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 104          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 68.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 765         |
# |    ep_rew_mean          | 92.6        |
# | time/                   |             |
# |    fps                  | 979         |
# |    iterations           | 28          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.002477863 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 103         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 782         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 29          |
# |    time_elapsed         | 488         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004451084 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.937      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.7        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.000534   |
# |    value_loss           | 54.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 797          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 30           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0037904386 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.4         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.000405    |
# |    value_loss           | 117          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 800          |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 31           |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0036566046 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.88         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000319    |
# |    value_loss           | 28.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 32          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.004379082 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.929      |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 855         |
# |    ep_rew_mean          | 123         |
# | time/                   |             |
# |    fps                  | 941         |
# |    iterations           | 33          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 540672      |
# | train/                  |             |
# |    approx_kl            | 0.004728293 |
# |    clip_fraction        | 0.0476      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78          |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.000338   |
# |    value_loss           | 55.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 858          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 936          |
# |    iterations           | 34           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0043202154 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 28.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 888         |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 931         |
# |    iterations           | 35          |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.005436401 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 22.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 911          |
# |    ep_rew_mean          | 132          |
# | time/                   |              |
# |    fps                  | 926          |
# |    iterations           | 36           |
# |    time_elapsed         | 636          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0048679663 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.09         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000797    |
# |    value_loss           | 17           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 924         |
# |    iterations           | 37          |
# |    time_elapsed         | 655         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.005898119 |
# |    clip_fraction        | 0.0378      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.875       |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 948         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 38          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.004160771 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.8        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 36.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 947         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 918         |
# |    iterations           | 39          |
# |    time_elapsed         | 695         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.006015179 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.967      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.00023    |
# |    value_loss           | 27.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 40          |
# |    time_elapsed         | 716         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.004033279 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.000299   |
# |    value_loss           | 26.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 952         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 41          |
# |    time_elapsed         | 736         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.004313248 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.11        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.000369   |
# |    value_loss           | 10.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 951         |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 909         |
# |    iterations           | 42          |
# |    time_elapsed         | 756         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004720305 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 164         |
# |    policy_gradient_loss | -0.000936   |
# |    value_loss           | 24.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 905          |
# |    iterations           | 43           |
# |    time_elapsed         | 778          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0048116585 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.934       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.000552    |
# |    value_loss           | 20.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 44          |
# |    time_elapsed         | 799         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.005346028 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 7.38        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 960          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 45           |
# |    time_elapsed         | 819          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0035229623 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 33.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 46          |
# |    time_elapsed         | 842         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.006352679 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.99        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000113    |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 47          |
# |    time_elapsed         | 863         |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.004523449 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56        |
# |    n_updates            | 184         |
# |    policy_gradient_loss | -0.000886   |
# |    value_loss           | 5.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 968          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 887          |
# |    iterations           | 48           |
# |    time_elapsed         | 885          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0044090413 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 21.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 976          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 49           |
# |    time_elapsed         | 909          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0062640514 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.908       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.000134    |
# |    value_loss           | 5.54         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 878          |
# |    iterations           | 50           |
# |    time_elapsed         | 931          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0053310925 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.842       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.593        |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00075     |
# |    value_loss           | 3.11         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 51           |
# |    time_elapsed         | 952          |
# |    total_timesteps      | 835584       |
# | train/                  |              |
# |    approx_kl            | 0.0032080193 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.01         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 25.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 987          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 52           |
# |    time_elapsed         | 972          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0039566513 |
# |    clip_fraction        | 0.0348       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.847       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000434    |
# |    value_loss           | 3.8          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 964         |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 53          |
# |    time_elapsed         | 993         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.004442016 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.000994   |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 947          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 872          |
# |    iterations           | 54           |
# |    time_elapsed         | 1013         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0040906845 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.961        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 67.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 928         |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 55          |
# |    time_elapsed         | 1032        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.002470209 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0.974       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 41.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 928          |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 56           |
# |    time_elapsed         | 1053         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0021335864 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7            |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00052     |
# |    value_loss           | 52.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 892          |
# |    ep_rew_mean          | 173          |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 57           |
# |    time_elapsed         | 1072         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0044368315 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2          |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000855    |
# |    value_loss           | 35.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 874         |
# |    ep_rew_mean          | 183         |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 58          |
# |    time_elapsed         | 1092        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.004850301 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.724      |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.6        |
# |    n_updates            | 228         |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 133         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 59           |
# |    time_elapsed         | 1111         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0052078697 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.665       |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.4         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 653          |
# |    ep_rew_mean          | 230          |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 60           |
# |    time_elapsed         | 1128         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0039441637 |
# |    clip_fraction        | 0.0751       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.883        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 167          |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 272          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 445         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 61          |
# |    time_elapsed         | 1143        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.008178514 |
# |    clip_fraction        | 0.0757      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.623      |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 338         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 387         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 307         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 62          |
# |    time_elapsed         | 1157        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.014041025 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 161         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 305         |
# -----------------------------------------

# %%
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=257.98 +/- 24.43766811397552

# %%
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import gymnasium as gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub


env_id = "LunarLander-v2"


model_architecture = "PPO"


repo_id = "Anandbheesetti/Lunar_Lander_By_using_reinforcement_learning"


commit_message = "Upload PPO LunarLander-v2 trained agent"


eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])

package_to_hub(model=model,
               model_name=model_name,
               model_architecture=model_architecture,
               env_id=env_id,
               eval_env=eval_env,
               repo_id=repo_id,
               commit_message=commit_message)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Saving video to /tmp/tmp7zvlgibq/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp7zvlgibq/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp7zvlgibq/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp7zvlgibq/-step-0-to-step-1000.mp4
# ℹ Pushing repo
# Anandbheesetti/Lunar_Lander_By_using_reinforcement_learning to the Hugging Face
# Hub
# policy.optimizer.pth:   0%|          | 0.00/88.4k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# policy.pth:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# ppo-LunarLander-v2.zip:   0%|          | 0.00/148k [00:00<?, ?B/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/Anandbheesetti/Lunar_Lander_By_using_reinforcement_learning/tree/main/
# 'https://huggingface.co/Anandbheesetti/Lunar_Lander_By_using_reinforcement_learning/tree/main/'
